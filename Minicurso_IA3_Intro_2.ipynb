# %% [markdown]
# <a href="https://colab.research.google.com/github/aumana/EOAI/blob/main/Minicurso_IA3_Intro_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Redes Neurais Convolucionais

# %% [markdown]
# Uma Rede Neural Convolucional (ConvNet / Convolutional Neural Network / CNN) é um algoritmo de Aprendizado Profundo que pode captar uma imagem de entrada, atribuir importância (pesos e vieses que podem ser aprendidos) a vários aspectos / objetos da imagem e ser capaz de diferenciar um do outro. O pré-processamento exigido em uma ConvNet é muito menor em comparação com outros algoritmos de classificação. Enquanto nos métodos primitivos os filtros são feitos à mão, com treinamento suficiente, as ConvNets têm a capacidade de aprender esses filtros / características. Em 1962, Hubel e Wiesel fizeram um experimento mostrando que alguns neurônios são ativados juntos quando expostos a algumas linhas ou curvas, conseguindo assim produzir o reconhecimento visual.
# Essa é a basicamente a ideia principal de uma Rede Convolucional: filtrar linhas, curvas e bordas e em cada camada acrescida transformar essa filtragem em uma imagem mais complexa.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# CNN X ANN

# %% [markdown]
# Uma imagem não é nada além de uma matriz de valores de pixels, certo? Então, por que não apenas achatar a imagem (por exemplo, converter uma matriz 3×3 em um vetor 9×1. Se a image é uma matriz, nenhum problema em converter em uma vetor) e alimentá-lo para um Perceptron Multi-Layer para fins de classificação? Na verdade não.
#
# Em casos de imagens binárias extremamente básicas, o método pode mostrar uma pontuação de precisão média durante a previsão de classes, mas teria pouca ou nenhuma precisão quando se trata de imagens complexas com dependências de pixel por toda parte.
#
# Uma ConvNet é capaz de capturar com sucesso as dependências espaciais e temporais em uma imagem através da aplicação de filtros relevantes. A arquitetura executa um melhor ajuste ao conjunto de dados da imagem devido à redução no número de parâmetros envolvidos e à capacidade de reutilização dos pesos. Em outras palavras, a rede pode ser treinada para entender melhor a sofisticação da imagem.

# %% [markdown]
# Quando falamos em reconhecimento/classificação de imagens, as entradas são usualmente matrizes tridimensionais com altura e largura (de acordo com as dimensões da imagem) e profundidade, determinada pela quantidade de canais de cores. Em geral as imagens utilizam três canais, RGB, com os valores de cada pixel.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Kernels Convolucionais

# %% [markdown]
# Um kernel é um filtro que utilizaremos em nossas imagens. Ele passará por toda a imagem, da esquerda para a direita, de cima para baixo, aplicando o produto da convolução. No final, teremos uma imagem filtrada.

# %% [markdown]
# No processamento de imagens, um kernel de convolução é uma matriz 2D usada para filtrar imagens. Também conhecido como uma matriz de convolução, um kernel de convolução é tipicamente um quadrado, matriz MxN, onde M e N são inteiros ímpares (por exemplo, 3 × 3, 5 × 5, 7 × 7 etc.). Veja a matriz de exemplo 3 × 3 fornecida abaixo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# kernel de convolução 2D 3 × 3
#
# Esses kernels podem ser usados para realizar operações matemáticas em cada pixel de uma imagem para obter o efeito desejado (como embaçar ou aumentar a nitidez de uma imagem). Mas por que você deseja desfocar uma imagem? Aqui estão dois motivos importantes:
#
# Porque reduz certos tipos de ruído em uma imagem. Por esse motivo, o embaçamento costuma ser chamado de suavização.
# Para remover uma distração do fundo, você pode desfocar intencionalmente partes de uma imagem, como é feito no modo 'Retrato', em câmeras de dispositivos móveis.
# Por ser uma técnica de processamento fundamental em Visão Computacional, a filtragem de imagens com kernels tem muito mais aplicações.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Convoluções

# %% [markdown]
# As convoluções funcionam como filtros que enxergam pequenos quadrados e vão “escorregando” por toda a imagem captando os traços mais marcantes. Explicando melhor, com uma imagem 32x32x3 e um filtro que cobre uma área de 5x5 da imagem com movimento de 2 saltos (chamado de stride), o filtro passará pela imagem inteira, por cada um dos canais, formando no final um feature map ou activation map de 28x28x1.
# A profundidade da saída de uma convolução é igual a quantidade de filtros aplicados. Quanto mais profundas são as camadas das convoluções, mais detalhados são os traços identificados com o activation map.
# O filtro, que também é conhecido por kernel, é formado por pesos inicializados aleatoriamente, atualizando-os a cada nova entrada durante o processo de backpropagation. A pequena região da entrada onde o filtro é aplicado é chamada de receptive field.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Camada de Pooling

# %% [markdown]
# Uma camada de pooling serve para simplificar a informação da camada anterior. Assim como na convolução, é escolhida uma unidade de área, por exemplo 2x2, para transitar por toda a saída da camada anterior. A unidade é responsável por resumir a informação daquela área em um único valor. Se a saída da camada anterior for 24x24, a saída do pooling será 12x12. Além disso, é preciso escolher como será feita a sumarização. O método mais utilizado é o maxpooling, no qual apenas o maior número da unidade é passado para a saída. Essa sumarização de dados serve para diminuir a quantidade de pesos a serem aprendidos e também para evitar overfitting.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Camada Flatten

# %% [markdown]
# Essa camada normalmente é utilizada na divisão das 2 partes da CNN (extração de características / rede neural tradicional ). Ela basicamente opera uma transformação na matrix da imagem, alterando seu formato para um array. Por exemplo, uma imagem em grayscale de 28x28 será transformada para um array de 784 posições. A imagem abaixo ilustra essa operação.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Camada Densa

# %% [markdown]
# Ao final da rede é colocada uma camada Fully connected, onde sua entrada é a saída da camada anterior e sua saída são N neurônios, com N sendo a quantidade de classes do seu modelo para finalizar a classificação.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Camada de Ativação final para a classificação

# %% [markdown]
#  - Sigmoide: Na camada de saída, a função sigmoide é útil para produzir probabilidades em problemas de classificação binária, já que seus resultados, na faixa de [0, 1], podem ser interpretados como a probabilidade de determinada instância pertencer ou não a determinada classe.
#
#  - Softmax: Softmax é uma generalização da função sigmoide para casos não-binários. Ela não costuma ser aplicada às camadas escondidas da rede neural, mas sim na camada de saída de problemas de classificação multiclasse, já que sua característica é produzir valores no intervalo [0, 1] onde sua soma é igual a 1. Ou seja, num problema com 3 classes, por exemplo, a função softmax vai produzir 3 valores, que somam 1, onde cada valor representa a probabilidade da instância pertencer a uma das 3 possíveis classes.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Link para acessar o dataset: https://drive.google.com/drive/folders/1_jfLD8yjmbEexfFnvn9yOcb6DmPkKAR9?usp=sharing

# %%
# !pip install geopandas
# !pip install rasterio
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.9.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (23.2)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.5.3)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.2)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (2024.2.2)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (67.7.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2023.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (1.23.5)
# Collecting rasterio
#   Downloading rasterio-1.3.9-cp310-cp310-manylinux2014_x86_64.whl (20.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 41.1 MB/s eta 0:00:00
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio) (2024.2.2)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.23.5)
# Collecting snuggs>=1.4.1 (from rasterio)
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio) (67.7.2)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.10/dist-packages (from snuggs>=1.4.1->rasterio) (3.1.1)
# Installing collected packages: snuggs, affine, rasterio
# Successfully installed affine-2.4.0 rasterio-1.3.9 snuggs-1.4.7

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np
import rasterio
import pandas as pd
from pylab import rcParams
import matplotlib
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 14
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'
import seaborn as sns
plt.style.use('fivethirtyeight')
rcParams['figure.figsize'] = 18, 6
from sklearn.model_selection import train_test_split

# %% [markdown]
# Vamos definir os caminhos:

# %%
path_train = '/content/drive/MyDrive/Datasets/Pivot_classification/train_dataset'
path_test = '/content/drive/MyDrive/Datasets/Pivot_classification/teste'

# %%
class_list = os.listdir(path_train)

# %% [markdown]
# Vamos listar as classes que temos em nosso conjunto de dados e importar as imagens:

# %%
print(class_list)
# Out:
# ['pivot', 'not_pivot']

# %%
Y = []
X = []
i = 0
for i in range(len(class_list)):
  path_class = os.path.join(path_train,class_list[i])
  img_list = os.listdir(path_class)
  for n in range(len(img_list)):
    path_img = os.path.join(path_class,img_list[n])
    src = rasterio.open(path_img)
    im = src.read()
    im = im.transpose([1,2,0])
    im = im.astype('uint8')
    print(str(n) + '_' + class_list[i])
    Y.append(i)
    X.append(im)
# Out:
# /usr/local/lib/python3.10/dist-packages/rasterio/__init__.py:304: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# 0_pivot
# 1_pivot
# 2_pivot
# 3_pivot
# 4_pivot
# 5_pivot
# 6_pivot
# 7_pivot
# 8_pivot
# 9_pivot
# 10_pivot
# 11_pivot
# 12_pivot
# 13_pivot
# 14_pivot
# 15_pivot
# 16_pivot
# 17_pivot
# 18_pivot
# 19_pivot
# 20_pivot
# 21_pivot
# 22_pivot
# 23_pivot
# 24_pivot
# 25_pivot
# 26_pivot
# 27_pivot
# 28_pivot
# 29_pivot
# 30_pivot
# 31_pivot
# 32_pivot
# 33_pivot
# 34_pivot
# 35_pivot
# 36_pivot
# 37_pivot
# 38_pivot
# 39_pivot
# 40_pivot
# 41_pivot
# 42_pivot
# 43_pivot
# 44_pivot
# 45_pivot
# 46_pivot
# 47_pivot
# 48_pivot
# 49_pivot
# 50_pivot
# 51_pivot
# 52_pivot
# 53_pivot
# 54_pivot
# 55_pivot
# 56_pivot
# 57_pivot
# 58_pivot
# 59_pivot
# 60_pivot
# 61_pivot
# 62_pivot
# 63_pivot
# 64_pivot
# 65_pivot
# 66_pivot
# 67_pivot
# 68_pivot
# 69_pivot
# 70_pivot
# 71_pivot
# 72_pivot
# 73_pivot
# 74_pivot
# 75_pivot
# 76_pivot
# 77_pivot
# 78_pivot
# 79_pivot
# 80_pivot
# 81_pivot
# 82_pivot
# 83_pivot
# 84_pivot
# 85_pivot
# 86_pivot
# 87_pivot
# 88_pivot
# 89_pivot
# 90_pivot
# 91_pivot
# 92_pivot
# 93_pivot
# 94_pivot
# 95_pivot
# 96_pivot
# 97_pivot
# 98_pivot
# 99_pivot
# 100_pivot
# 101_pivot
# 102_pivot
# 103_pivot
# 104_pivot
# 105_pivot
# 106_pivot
# 107_pivot
# 108_pivot
# 109_pivot
# 110_pivot
# 111_pivot
# 112_pivot
# 113_pivot
# 114_pivot
# 115_pivot
# 116_pivot
# 117_pivot
# 118_pivot
# 119_pivot
# 120_pivot
# 121_pivot
# 122_pivot
# 123_pivot
# 124_pivot
# 125_pivot
# 126_pivot
# 127_pivot
# 128_pivot
# 129_pivot
# 130_pivot
# 131_pivot
# 132_pivot
# 133_pivot
# 134_pivot
# 135_pivot
# 136_pivot
# 137_pivot
# 138_pivot
# 139_pivot
# 140_pivot
# 141_pivot
# 142_pivot
# 143_pivot
# 144_pivot
# 145_pivot
# 146_pivot
# 147_pivot
# 148_pivot
# 149_pivot
# 150_pivot
# 151_pivot
# 152_pivot
# 153_pivot
# 154_pivot
# 155_pivot
# 156_pivot
# 157_pivot
# 158_pivot
# 159_pivot
# 160_pivot
# 161_pivot
# 162_pivot
# 163_pivot
# 164_pivot
# 165_pivot
# 166_pivot
# 167_pivot
# 168_pivot
# 169_pivot
# 170_pivot
# 171_pivot
# 172_pivot
# 173_pivot
# 174_pivot
# 175_pivot
# 176_pivot
# 177_pivot
# 178_pivot
# 179_pivot
# 180_pivot
# 181_pivot
# 182_pivot
# 183_pivot
# 184_pivot
# 185_pivot
# 186_pivot
# 187_pivot
# 188_pivot
# 189_pivot
# 190_pivot
# 191_pivot
# 192_pivot
# 193_pivot
# 194_pivot
# 195_pivot
# 196_pivot
# 197_pivot
# 198_pivot
# 199_pivot
# 200_pivot
# 201_pivot
# 202_pivot
# 203_pivot
# 204_pivot
# 205_pivot
# 206_pivot
# 207_pivot
# 208_pivot
# 209_pivot
# 210_pivot
# 211_pivot
# 212_pivot
# 213_pivot
# 214_pivot
# 215_pivot
# 216_pivot
# 217_pivot
# 218_pivot
# 219_pivot
# 220_pivot
# 221_pivot
# 222_pivot
# 223_pivot
# 224_pivot
# 225_pivot
# 226_pivot
# 227_pivot
# 228_pivot
# 229_pivot
# 230_pivot
# 231_pivot
# 232_pivot
# 233_pivot
# 234_pivot
# 235_pivot
# 236_pivot
# 237_pivot
# 238_pivot
# 239_pivot
# 240_pivot
# 241_pivot
# 242_pivot
# 243_pivot
# 244_pivot
# 245_pivot
# 246_pivot
# 247_pivot
# 248_pivot
# 249_pivot
# 250_pivot
# 251_pivot
# 252_pivot
# 253_pivot
# 254_pivot
# 255_pivot
# 256_pivot
# 257_pivot
# 258_pivot
# 259_pivot
# 260_pivot
# 261_pivot
# 262_pivot
# 263_pivot
# 264_pivot
# 265_pivot
# 266_pivot
# 267_pivot
# 268_pivot
# 269_pivot
# 270_pivot
# 271_pivot
# 272_pivot
# 273_pivot
# 274_pivot
# 275_pivot
# 276_pivot
# 277_pivot
# 278_pivot
# 279_pivot
# 280_pivot
# 281_pivot
# 282_pivot
# 283_pivot
# 284_pivot
# 285_pivot
# 286_pivot
# 287_pivot
# 288_pivot
# 289_pivot
# 290_pivot
# 291_pivot
# 292_pivot
# 293_pivot
# 294_pivot
# 295_pivot
# 296_pivot
# 297_pivot
# 298_pivot
# 299_pivot
# 300_pivot
# 301_pivot
# 302_pivot
# 303_pivot
# 304_pivot
# 305_pivot
# 306_pivot
# 307_pivot
# 308_pivot
# 309_pivot
# 310_pivot
# 311_pivot
# 312_pivot
# 313_pivot
# 314_pivot
# 315_pivot
# 316_pivot
# 317_pivot
# 318_pivot
# 319_pivot
# 320_pivot
# 321_pivot
# 322_pivot
# 323_pivot
# 324_pivot
# 325_pivot
# 326_pivot
# 327_pivot
# 328_pivot
# 329_pivot
# 330_pivot
# 331_pivot
# 332_pivot
# 333_pivot
# 334_pivot
# 335_pivot
# 336_pivot
# 337_pivot
# 338_pivot
# 339_pivot
# 340_pivot
# 341_pivot
# 342_pivot
# 343_pivot
# 344_pivot
# 345_pivot
# 346_pivot
# 347_pivot
# 348_pivot
# 349_pivot
# 350_pivot
# 351_pivot
# 352_pivot
# 353_pivot
# 354_pivot
# 355_pivot
# 356_pivot
# 357_pivot
# 358_pivot
# 359_pivot
# 360_pivot
# 361_pivot
# 362_pivot
# 363_pivot
# 364_pivot
# 365_pivot
# 366_pivot
# 367_pivot
# 368_pivot
# 369_pivot
# 370_pivot
# 371_pivot
# 372_pivot
# 373_pivot
# 374_pivot
# 375_pivot
# 376_pivot
# 377_pivot
# 378_pivot
# 379_pivot
# 380_pivot
# 381_pivot
# 382_pivot
# 383_pivot
# 384_pivot
# 385_pivot
# 386_pivot
# 387_pivot
# 388_pivot
# 389_pivot
# 390_pivot
# 391_pivot
# 392_pivot
# 393_pivot
# 394_pivot
# 395_pivot
# 396_pivot
# 397_pivot
# 398_pivot
# 399_pivot
# 400_pivot
# 401_pivot
# 402_pivot
# 403_pivot
# 404_pivot
# 405_pivot
# 406_pivot
# 407_pivot
# 408_pivot
# 409_pivot
# 410_pivot
# 411_pivot
# 412_pivot
# 413_pivot
# 414_pivot
# 415_pivot
# 416_pivot
# 417_pivot
# 418_pivot
# 419_pivot
# 420_pivot
# 421_pivot
# 422_pivot
# 423_pivot
# 424_pivot
# 425_pivot
# 426_pivot
# 427_pivot
# 428_pivot
# 429_pivot
# 430_pivot
# 431_pivot
# 432_pivot
# 433_pivot
# 434_pivot
# 435_pivot
# 436_pivot
# 437_pivot
# 438_pivot
# 439_pivot
# 440_pivot
# 441_pivot
# 442_pivot
# 443_pivot
# 444_pivot
# 445_pivot
# 446_pivot
# 447_pivot
# 448_pivot
# 449_pivot
# 450_pivot
# 451_pivot
# 452_pivot
# 453_pivot
# 454_pivot
# 455_pivot
# 456_pivot
# 457_pivot
# 458_pivot
# 459_pivot
# 460_pivot
# 461_pivot
# 462_pivot
# 463_pivot
# 464_pivot
# 465_pivot
# 466_pivot
# 467_pivot
# 468_pivot
# 469_pivot
# 470_pivot
# 471_pivot
# 472_pivot
# 473_pivot
# 474_pivot
# 475_pivot
# 476_pivot
# 477_pivot
# 478_pivot
# 479_pivot
# 480_pivot
# 481_pivot
# 482_pivot
# 483_pivot
# 484_pivot
# 485_pivot
# 486_pivot
# 487_pivot
# 488_pivot
# 489_pivot
# 490_pivot
# 491_pivot
# 492_pivot
# 493_pivot
# 494_pivot
# 495_pivot
# 496_pivot
# 497_pivot
# 498_pivot
# 499_pivot
# 500_pivot
# 501_pivot
# 502_pivot
# 503_pivot
# 504_pivot
# 505_pivot
# 506_pivot
# 507_pivot
# 508_pivot
# 509_pivot
# 510_pivot
# 511_pivot
# 512_pivot
# 513_pivot
# 514_pivot
# 515_pivot
# 516_pivot
# 517_pivot
# 518_pivot
# 519_pivot
# 520_pivot
# 521_pivot
# 522_pivot
# 523_pivot
# 524_pivot
# 525_pivot
# 526_pivot
# 527_pivot
# 528_pivot
# 529_pivot
# 530_pivot
# 531_pivot
# 532_pivot
# 533_pivot
# 534_pivot
# 535_pivot
# 536_pivot
# 537_pivot
# 538_pivot
# 539_pivot
# 540_pivot
# 541_pivot
# 542_pivot
# 543_pivot
# 544_pivot
# 545_pivot
# 546_pivot
# 547_pivot
# 548_pivot
# 549_pivot
# 550_pivot
# 551_pivot
# 552_pivot
# 553_pivot
# 554_pivot
# 555_pivot
# 556_pivot
# 557_pivot
# 558_pivot
# 559_pivot
# 560_pivot
# 561_pivot
# 562_pivot
# 563_pivot
# 564_pivot
# 565_pivot
# 566_pivot
# 567_pivot
# 568_pivot
# 569_pivot
# 570_pivot
# 571_pivot
# 572_pivot
# 573_pivot
# 574_pivot
# 575_pivot
# 576_pivot
# 577_pivot
# 578_pivot
# 579_pivot
# 580_pivot
# 581_pivot
# 582_pivot
# 583_pivot
# 584_pivot
# 585_pivot
# 586_pivot
# 587_pivot
# 588_pivot
# 589_pivot
# 590_pivot
# 591_pivot
# 592_pivot
# 593_pivot
# 594_pivot
# 595_pivot
# 596_pivot
# 597_pivot
# 598_pivot
# 599_pivot
# 600_pivot
# 601_pivot
# 602_pivot
# 603_pivot
# 604_pivot
# 605_pivot
# 606_pivot
# 607_pivot
# 608_pivot
# 609_pivot
# 610_pivot
# 611_pivot
# 612_pivot
# 613_pivot
# 614_pivot
# 615_pivot
# 616_pivot
# 617_pivot
# 618_pivot
# 619_pivot
# 620_pivot
# 621_pivot
# 622_pivot
# 623_pivot
# 624_pivot
# 625_pivot
# 626_pivot
# 627_pivot
# 628_pivot
# 629_pivot
# 630_pivot
# 631_pivot
# 632_pivot
# 633_pivot
# 634_pivot
# 635_pivot
# 636_pivot
# 637_pivot
# 638_pivot
# 639_pivot
# 640_pivot
# 641_pivot
# 642_pivot
# 643_pivot
# 644_pivot
# 645_pivot
# 646_pivot
# 647_pivot
# 648_pivot
# 649_pivot
# 650_pivot
# 651_pivot
# 652_pivot
# 653_pivot
# 654_pivot
# 655_pivot
# 656_pivot
# 657_pivot
# 658_pivot
# 659_pivot
# 660_pivot
# 661_pivot
# 662_pivot
# 663_pivot
# 664_pivot
# 665_pivot
# 666_pivot
# 667_pivot
# 668_pivot
# 669_pivot
# 670_pivot
# 671_pivot
# 672_pivot
# 673_pivot
# 674_pivot
# 675_pivot
# 676_pivot
# 677_pivot
# 678_pivot
# 679_pivot
# 680_pivot
# 681_pivot
# 682_pivot
# 683_pivot
# 684_pivot
# 685_pivot
# 686_pivot
# 687_pivot
# 688_pivot
# 689_pivot
# 690_pivot
# 691_pivot
# 692_pivot
# 693_pivot
# 694_pivot
# 695_pivot
# 696_pivot
# 697_pivot
# 698_pivot
# 699_pivot
# 700_pivot
# 701_pivot
# 702_pivot
# 703_pivot
# 704_pivot
# 705_pivot
# 706_pivot
# 707_pivot
# 708_pivot
# 709_pivot
# 710_pivot
# 711_pivot
# 712_pivot
# 713_pivot
# 714_pivot
# 715_pivot
# 716_pivot
# 717_pivot
# 718_pivot
# 719_pivot
# 720_pivot
# 721_pivot
# 722_pivot
# 723_pivot
# 724_pivot
# 725_pivot
# 726_pivot
# 727_pivot
# 728_pivot
# 729_pivot
# 730_pivot
# 731_pivot
# 732_pivot
# 733_pivot
# 734_pivot
# 735_pivot
# 736_pivot
# 737_pivot
# 738_pivot
# 739_pivot
# 740_pivot
# 741_pivot
# 742_pivot
# 743_pivot
# 744_pivot
# 745_pivot
# 746_pivot
# 747_pivot
# 748_pivot
# 749_pivot
# 750_pivot
# 751_pivot
# 752_pivot
# 753_pivot
# 754_pivot
# 755_pivot
# 756_pivot
# 757_pivot
# 758_pivot
# 759_pivot
# 760_pivot
# 761_pivot
# 762_pivot
# 763_pivot
# 764_pivot
# 765_pivot
# 766_pivot
# 767_pivot
# 768_pivot
# 769_pivot
# 770_pivot
# 771_pivot
# 772_pivot
# 773_pivot
# 774_pivot
# 775_pivot
# 776_pivot
# 777_pivot
# 778_pivot
# 779_pivot
# 780_pivot
# 781_pivot
# 782_pivot
# 783_pivot
# 784_pivot
# 785_pivot
# 786_pivot
# 787_pivot
# 788_pivot
# 789_pivot
# 790_pivot
# 791_pivot
# 792_pivot
# 793_pivot
# 794_pivot
# 795_pivot
# 796_pivot
# 797_pivot
# 798_pivot
# 799_pivot
# 800_pivot
# 801_pivot
# 802_pivot
# 803_pivot
# 804_pivot
# 805_pivot
# 806_pivot
# 807_pivot
# 808_pivot
# 809_pivot
# 810_pivot
# 811_pivot
# 812_pivot
# 813_pivot
# 814_pivot
# 815_pivot
# 816_pivot
# 817_pivot
# 818_pivot
# 819_pivot
# 820_pivot
# 821_pivot
# 822_pivot
# 823_pivot
# 824_pivot
# 825_pivot
# 826_pivot
# 827_pivot
# 828_pivot
# 829_pivot
# 830_pivot
# 831_pivot
# 832_pivot
# 833_pivot
# 834_pivot
# 835_pivot
# 836_pivot
# 837_pivot
# 838_pivot
# 839_pivot
# 840_pivot
# 841_pivot
# 842_pivot
# 843_pivot
# 844_pivot
# 845_pivot
# 846_pivot
# 847_pivot
# 848_pivot
# 849_pivot
# 850_pivot
# 851_pivot
# 852_pivot
# 853_pivot
# 854_pivot
# 855_pivot
# 856_pivot
# 857_pivot
# 858_pivot
# 859_pivot
# 860_pivot
# 861_pivot
# 862_pivot
# 863_pivot
# 864_pivot
# 865_pivot
# 866_pivot
# 867_pivot
# 868_pivot
# 869_pivot
# 870_pivot
# 871_pivot
# 872_pivot
# 873_pivot
# 874_pivot
# 875_pivot
# 876_pivot
# 877_pivot
# 878_pivot
# 879_pivot
# 880_pivot
# 881_pivot
# 882_pivot
# 883_pivot
# 884_pivot
# 885_pivot
# 886_pivot
# 887_pivot
# 888_pivot
# 889_pivot
# 890_pivot
# 891_pivot
# 892_pivot
# 893_pivot
# 894_pivot
# 895_pivot
# 896_pivot
# 897_pivot
# 898_pivot
# 899_pivot
# 900_pivot
# 901_pivot
# 902_pivot
# 903_pivot
# 904_pivot
# 905_pivot
# 906_pivot
# 907_pivot
# 908_pivot
# 909_pivot
# 910_pivot
# 911_pivot
# 912_pivot
# 913_pivot
# 914_pivot
# 915_pivot
# 916_pivot
# 917_pivot
# 918_pivot
# 919_pivot
# 920_pivot
# 921_pivot
# 922_pivot
# 923_pivot
# 924_pivot
# 925_pivot
# 926_pivot
# 927_pivot
# 928_pivot
# 929_pivot
# 930_pivot
# 931_pivot
# 932_pivot
# 933_pivot
# 934_pivot
# 935_pivot
# 936_pivot
# 937_pivot
# 938_pivot
# 939_pivot
# 940_pivot
# 941_pivot
# 942_pivot
# 943_pivot
# 944_pivot
# 945_pivot
# 946_pivot
# 947_pivot
# 948_pivot
# 949_pivot
# 950_pivot
# 951_pivot
# 952_pivot
# 953_pivot
# 954_pivot
# 955_pivot
# 956_pivot
# 957_pivot
# 958_pivot
# 959_pivot
# 960_pivot
# 961_pivot
# 962_pivot
# 963_pivot
# 964_pivot
# 965_pivot
# 966_pivot
# 967_pivot
# 968_pivot
# 969_pivot
# 970_pivot
# 971_pivot
# 972_pivot
# 973_pivot
# 974_pivot
# 975_pivot
# 976_pivot
# 977_pivot
# 978_pivot
# 979_pivot
# 980_pivot
# 981_pivot
# 982_pivot
# 983_pivot
# 984_pivot
# 985_pivot
# 986_pivot
# 987_pivot
# 988_pivot
# 989_pivot
# 990_pivot
# 991_pivot
# 992_pivot
# 993_pivot
# 994_pivot
# 995_pivot
# 996_pivot
# 997_pivot
# 998_pivot
# 999_pivot
# 1000_pivot
# 1001_pivot
# 1002_pivot
# 1003_pivot
# 1004_pivot
# 1005_pivot
# 1006_pivot
# 1007_pivot
# 1008_pivot
# 1009_pivot
# 1010_pivot
# 1011_pivot
# 1012_pivot
# 1013_pivot
# 1014_pivot
# 1015_pivot
# 1016_pivot
# 1017_pivot
# 1018_pivot
# 1019_pivot
# 1020_pivot
# 1021_pivot
# 1022_pivot
# 1023_pivot
# 1024_pivot
# 1025_pivot
# 1026_pivot
# 1027_pivot
# 1028_pivot
# 1029_pivot
# 1030_pivot
# 1031_pivot
# 1032_pivot
# 1033_pivot
# 1034_pivot
# 1035_pivot
# 1036_pivot
# 1037_pivot
# 1038_pivot
# 1039_pivot
# 1040_pivot
# 1041_pivot
# 1042_pivot
# 1043_pivot
# 1044_pivot
# 1045_pivot
# 1046_pivot
# 1047_pivot
# 1048_pivot
# 1049_pivot
# 1050_pivot
# 1051_pivot
# 1052_pivot
# 1053_pivot
# 1054_pivot
# 1055_pivot
# 1056_pivot
# 1057_pivot
# 1058_pivot
# 1059_pivot
# 1060_pivot
# 1061_pivot
# 1062_pivot
# 1063_pivot
# 1064_pivot
# 1065_pivot
# 1066_pivot
# 1067_pivot
# 1068_pivot
# 1069_pivot
# 1070_pivot
# 1071_pivot
# 1072_pivot
# 1073_pivot
# 1074_pivot
# 1075_pivot
# 1076_pivot
# 1077_pivot
# 1078_pivot
# 1079_pivot
# 1080_pivot
# 1081_pivot
# 1082_pivot
# 1083_pivot
# 1084_pivot
# 1085_pivot
# 1086_pivot
# 1087_pivot
# 1088_pivot
# 1089_pivot
# 1090_pivot
# 1091_pivot
# 1092_pivot
# 1093_pivot
# 1094_pivot
# 1095_pivot
# 1096_pivot
# 1097_pivot
# 1098_pivot
# 1099_pivot
# 1100_pivot
# 1101_pivot
# 1102_pivot
# 1103_pivot
# 1104_pivot
# 1105_pivot
# 1106_pivot
# 1107_pivot
# 1108_pivot
# 1109_pivot
# 1110_pivot
# 1111_pivot
# 1112_pivot
# 1113_pivot
# 1114_pivot
# 1115_pivot
# 1116_pivot
# 1117_pivot
# 1118_pivot
# 1119_pivot
# 1120_pivot
# 1121_pivot
# 1122_pivot
# 1123_pivot
# 1124_pivot
# 1125_pivot
# 1126_pivot
# 1127_pivot
# 1128_pivot
# 1129_pivot
# 1130_pivot
# 1131_pivot
# 1132_pivot
# 1133_pivot
# 1134_pivot
# 1135_pivot
# 1136_pivot
# 1137_pivot
# 1138_pivot
# 1139_pivot
# 1140_pivot
# 1141_pivot
# 1142_pivot
# 1143_pivot
# 1144_pivot
# 1145_pivot
# 1146_pivot
# 1147_pivot
# 1148_pivot
# 1149_pivot
# 1150_pivot
# 1151_pivot
# 1152_pivot
# 1153_pivot
# 1154_pivot
# 1155_pivot
# 1156_pivot
# 1157_pivot
# 1158_pivot
# 1159_pivot
# 1160_pivot
# 1161_pivot
# 1162_pivot
# 1163_pivot
# 1164_pivot
# 1165_pivot
# 1166_pivot
# 1167_pivot
# 1168_pivot
# 1169_pivot
# 1170_pivot
# 1171_pivot
# 1172_pivot
# 1173_pivot
# 1174_pivot
# 1175_pivot
# 1176_pivot
# 1177_pivot
# 1178_pivot
# 1179_pivot
# 1180_pivot
# 1181_pivot
# 1182_pivot
# 1183_pivot
# 1184_pivot
# 1185_pivot
# 1186_pivot
# 1187_pivot
# 1188_pivot
# 1189_pivot
# 1190_pivot
# 1191_pivot
# 1192_pivot
# 1193_pivot
# 1194_pivot
# 1195_pivot
# 1196_pivot
# 1197_pivot
# 1198_pivot
# 1199_pivot
# 1200_pivot
# 1201_pivot
# 1202_pivot
# 1203_pivot
# 1204_pivot
# 1205_pivot
# 1206_pivot
# 1207_pivot
# 1208_pivot
# 1209_pivot
# 1210_pivot
# 1211_pivot
# 1212_pivot
# 1213_pivot
# 1214_pivot
# 1215_pivot
# 1216_pivot
# 1217_pivot
# 1218_pivot
# 1219_pivot
# 1220_pivot
# 1221_pivot
# 1222_pivot
# 1223_pivot
# 1224_pivot
# 1225_pivot
# 1226_pivot
# 1227_pivot
# 1228_pivot
# 1229_pivot
# 1230_pivot
# 1231_pivot
# 1232_pivot
# 1233_pivot
# 1234_pivot
# 1235_pivot
# 1236_pivot
# 1237_pivot
# 1238_pivot
# 1239_pivot
# 1240_pivot
# 1241_pivot
# 1242_pivot
# 1243_pivot
# 1244_pivot
# 1245_pivot
# 1246_pivot
# 1247_pivot
# 1248_pivot
# 1249_pivot
# 1250_pivot
# 1251_pivot
# 1252_pivot
# 1253_pivot
# 1254_pivot
# 1255_pivot
# 1256_pivot
# 1257_pivot
# 1258_pivot
# 1259_pivot
# 1260_pivot
# 1261_pivot
# 1262_pivot
# 1263_pivot
# 1264_pivot
# 1265_pivot
# 1266_pivot
# 1267_pivot
# 1268_pivot
# 1269_pivot
# 1270_pivot
# 1271_pivot
# 1272_pivot
# 1273_pivot
# 1274_pivot
# 1275_pivot
# 1276_pivot
# 1277_pivot
# 1278_pivot
# 1279_pivot
# 1280_pivot
# 1281_pivot
# 1282_pivot
# 1283_pivot
# 1284_pivot
# 1285_pivot
# 1286_pivot
# 1287_pivot
# 1288_pivot
# 1289_pivot
# 1290_pivot
# 1291_pivot
# 1292_pivot
# 1293_pivot
# 1294_pivot
# 1295_pivot
# 1296_pivot
# 1297_pivot
# 1298_pivot
# 1299_pivot
# 1300_pivot
# 1301_pivot
# 1302_pivot
# 1303_pivot
# 1304_pivot
# 1305_pivot
# 1306_pivot
# 1307_pivot
# 1308_pivot
# 1309_pivot
# 1310_pivot
# 1311_pivot
# 1312_pivot
# 1313_pivot
# 1314_pivot
# 1315_pivot
# 1316_pivot
# 1317_pivot
# 1318_pivot
# 1319_pivot
# 1320_pivot
# 1321_pivot
# 1322_pivot
# 1323_pivot
# 1324_pivot
# 1325_pivot
# 1326_pivot
# 1327_pivot
# 1328_pivot
# 1329_pivot
# 1330_pivot
# 1331_pivot
# 1332_pivot
# 1333_pivot
# 1334_pivot
# 1335_pivot
# 1336_pivot
# 1337_pivot
# 1338_pivot
# 1339_pivot
# 1340_pivot
# 1341_pivot
# 1342_pivot
# 1343_pivot
# 1344_pivot
# 1345_pivot
# 1346_pivot
# 1347_pivot
# 1348_pivot
# 1349_pivot
# 1350_pivot
# 1351_pivot
# 1352_pivot
# 1353_pivot
# 1354_pivot
# 1355_pivot
# 1356_pivot
# 1357_pivot
# 1358_pivot
# 1359_pivot
# 1360_pivot
# 1361_pivot
# 1362_pivot
# 1363_pivot
# 1364_pivot
# 1365_pivot
# 1366_pivot
# 1367_pivot
# 1368_pivot
# 1369_pivot
# 1370_pivot
# 1371_pivot
# 1372_pivot
# 1373_pivot
# 1374_pivot
# 1375_pivot
# 1376_pivot
# 1377_pivot
# 1378_pivot
# 1379_pivot
# 1380_pivot
# 1381_pivot
# 1382_pivot
# 1383_pivot
# 1384_pivot
# 1385_pivot
# 1386_pivot
# 1387_pivot
# 1388_pivot
# 1389_pivot
# 1390_pivot
# 1391_pivot
# 1392_pivot
# 1393_pivot
# 1394_pivot
# 1395_pivot
# 1396_pivot
# 1397_pivot
# 1398_pivot
# 1399_pivot
# 1400_pivot
# 1401_pivot
# 1402_pivot
# 1403_pivot
# 1404_pivot
# 1405_pivot
# 1406_pivot
# 1407_pivot
# 1408_pivot
# 1409_pivot
# 1410_pivot
# 1411_pivot
# 1412_pivot
# 1413_pivot
# 1414_pivot
# 1415_pivot
# 1416_pivot
# 1417_pivot
# 1418_pivot
# 1419_pivot
# 1420_pivot
# 1421_pivot
# 1422_pivot
# 1423_pivot
# 1424_pivot
# 1425_pivot
# 1426_pivot
# 1427_pivot
# 1428_pivot
# 1429_pivot
# 1430_pivot
# 1431_pivot
# 1432_pivot
# 1433_pivot
# 1434_pivot
# 1435_pivot
# 1436_pivot
# 1437_pivot
# 1438_pivot
# 1439_pivot
# 1440_pivot
# 1441_pivot
# 1442_pivot
# 1443_pivot
# 1444_pivot
# 1445_pivot
# 1446_pivot
# 1447_pivot
# 1448_pivot
# 1449_pivot
# 1450_pivot
# 1451_pivot
# 1452_pivot
# 1453_pivot
# 1454_pivot
# 1455_pivot
# 1456_pivot
# 1457_pivot
# 1458_pivot
# 1459_pivot
# 1460_pivot
# 1461_pivot
# 1462_pivot
# 1463_pivot
# 1464_pivot
# 1465_pivot
# 1466_pivot
# 1467_pivot
# 1468_pivot
# 1469_pivot
# 1470_pivot
# 1471_pivot
# 1472_pivot
# 1473_pivot
# 1474_pivot
# 1475_pivot
# 1476_pivot
# 1477_pivot
# 1478_pivot
# 1479_pivot
# 1480_pivot
# 1481_pivot
# 1482_pivot
# 1483_pivot
# 1484_pivot
# 1485_pivot
# 1486_pivot
# 1487_pivot
# 1488_pivot
# 1489_pivot
# 1490_pivot
# 1491_pivot
# 1492_pivot
# 1493_pivot
# 1494_pivot
# 1495_pivot
# 1496_pivot
# 1497_pivot
# 1498_pivot
# 1499_pivot
# 1500_pivot
# 1501_pivot
# 1502_pivot
# 1503_pivot
# 1504_pivot
# 1505_pivot
# 1506_pivot
# 1507_pivot
# 1508_pivot
# 1509_pivot
# 1510_pivot
# 1511_pivot
# 1512_pivot
# 1513_pivot
# 1514_pivot
# 1515_pivot
# 1516_pivot
# 1517_pivot
# 1518_pivot
# 1519_pivot
# 1520_pivot
# 1521_pivot
# 1522_pivot
# 1523_pivot
# 1524_pivot
# 1525_pivot
# 1526_pivot
# 1527_pivot
# 1528_pivot
# 1529_pivot
# 1530_pivot
# 1531_pivot
# 1532_pivot
# 1533_pivot
# 1534_pivot
# 1535_pivot
# 1536_pivot
# 1537_pivot
# 1538_pivot
# 1539_pivot
# 1540_pivot
# 1541_pivot
# 1542_pivot
# 1543_pivot
# 1544_pivot
# 1545_pivot
# 1546_pivot
# 1547_pivot
# 1548_pivot
# 1549_pivot
# 1550_pivot
# 1551_pivot
# 1552_pivot
# 1553_pivot
# 1554_pivot
# 1555_pivot
# 1556_pivot
# 1557_pivot
# 1558_pivot
# 1559_pivot
# 1560_pivot
# 1561_pivot
# 1562_pivot
# 1563_pivot
# 1564_pivot
# 1565_pivot
# 1566_pivot
# 1567_pivot
# 1568_pivot
# 1569_pivot
# 1570_pivot
# 1571_pivot
# 1572_pivot
# 1573_pivot
# 1574_pivot
# 1575_pivot
# 1576_pivot
# 1577_pivot
# 1578_pivot
# 1579_pivot
# 1580_pivot
# 1581_pivot
# 1582_pivot
# 1583_pivot
# 1584_pivot
# 1585_pivot
# 1586_pivot
# 1587_pivot
# 1588_pivot
# 1589_pivot
# 1590_pivot
# 1591_pivot
# 1592_pivot
# 1593_pivot
# 1594_pivot
# 1595_pivot
# 1596_pivot
# 1597_pivot
# 1598_pivot
# 1599_pivot
# 1600_pivot
# 1601_pivot
# 1602_pivot
# 1603_pivot
# 1604_pivot
# 1605_pivot
# 1606_pivot
# 1607_pivot
# 1608_pivot
# 1609_pivot
# 1610_pivot
# 1611_pivot
# 1612_pivot
# 1613_pivot
# 1614_pivot
# 1615_pivot
# 1616_pivot
# 1617_pivot
# 1618_pivot
# 1619_pivot
# 1620_pivot
# 1621_pivot
# 1622_pivot
# 1623_pivot
# 1624_pivot
# 1625_pivot
# 1626_pivot
# 1627_pivot
# 1628_pivot
# 1629_pivot
# 1630_pivot
# 1631_pivot
# 1632_pivot
# 1633_pivot
# 1634_pivot
# 1635_pivot
# 1636_pivot
# 1637_pivot
# 1638_pivot
# 1639_pivot
# 1640_pivot
# 1641_pivot
# 1642_pivot
# 1643_pivot
# 1644_pivot
# 1645_pivot
# 1646_pivot
# 1647_pivot
# 1648_pivot
# 1649_pivot
# 1650_pivot
# 1651_pivot
# 1652_pivot
# 1653_pivot
# 1654_pivot
# 1655_pivot
# 1656_pivot
# 1657_pivot
# 1658_pivot
# 1659_pivot
# 1660_pivot
# 1661_pivot
# 1662_pivot
# 1663_pivot
# 1664_pivot
# 1665_pivot
# 1666_pivot
# 1667_pivot
# 1668_pivot
# 1669_pivot
# 1670_pivot
# 1671_pivot
# 1672_pivot
# 1673_pivot
# 1674_pivot
# 1675_pivot
# 1676_pivot
# 1677_pivot
# 1678_pivot
# 1679_pivot
# 1680_pivot
# 1681_pivot
# 1682_pivot
# 1683_pivot
# 1684_pivot
# 1685_pivot
# 1686_pivot
# 1687_pivot
# 1688_pivot
# 1689_pivot
# 1690_pivot
# 1691_pivot
# 1692_pivot
# 1693_pivot
# 1694_pivot
# 1695_pivot
# 1696_pivot
# 1697_pivot
# 1698_pivot
# 1699_pivot
# 1700_pivot
# 1701_pivot
# 1702_pivot
# 1703_pivot
# 1704_pivot
# 1705_pivot
# 1706_pivot
# 1707_pivot
# 1708_pivot
# 1709_pivot
# 1710_pivot
# 1711_pivot
# 1712_pivot
# 1713_pivot
# 1714_pivot
# 1715_pivot
# 1716_pivot
# 1717_pivot
# 1718_pivot
# 1719_pivot
# 1720_pivot
# 1721_pivot
# 1722_pivot
# 1723_pivot
# 1724_pivot
# 1725_pivot
# 1726_pivot
# 1727_pivot
# 1728_pivot
# 1729_pivot
# 1730_pivot
# 1731_pivot
# 1732_pivot
# 1733_pivot
# 1734_pivot
# 1735_pivot
# 1736_pivot
# 1737_pivot
# 1738_pivot
# 1739_pivot
# 1740_pivot
# 1741_pivot
# 1742_pivot
# 1743_pivot
# 1744_pivot
# 1745_pivot
# 1746_pivot
# 1747_pivot
# 1748_pivot
# 1749_pivot
# 1750_pivot
# 1751_pivot
# 1752_pivot
# 1753_pivot
# 1754_pivot
# 1755_pivot
# 1756_pivot
# 1757_pivot
# 1758_pivot
# 1759_pivot
# 1760_pivot
# 1761_pivot
# 1762_pivot
# 1763_pivot
# 1764_pivot
# 1765_pivot
# 1766_pivot
# 1767_pivot
# 1768_pivot
# 1769_pivot
# 1770_pivot
# 1771_pivot
# 1772_pivot
# 1773_pivot
# 1774_pivot
# 1775_pivot
# 1776_pivot
# 1777_pivot
# 1778_pivot
# 1779_pivot
# 1780_pivot
# 1781_pivot
# 1782_pivot
# 1783_pivot
# 1784_pivot
# 1785_pivot
# 1786_pivot
# 1787_pivot
# 1788_pivot
# 1789_pivot
# 1790_pivot
# 1791_pivot
# 1792_pivot
# 1793_pivot
# 1794_pivot
# 1795_pivot
# 1796_pivot
# 1797_pivot
# 1798_pivot
# 1799_pivot
# 1800_pivot
# 1801_pivot
# 1802_pivot
# 1803_pivot
# 1804_pivot
# 1805_pivot
# 0_not_pivot
# 1_not_pivot
# 2_not_pivot
# 3_not_pivot
# 4_not_pivot
# 5_not_pivot
# 6_not_pivot
# 7_not_pivot
# 8_not_pivot
# 9_not_pivot
# 10_not_pivot
# 11_not_pivot
# 12_not_pivot
# 13_not_pivot
# 14_not_pivot
# 15_not_pivot
# 16_not_pivot
# 17_not_pivot
# 18_not_pivot
# 19_not_pivot
# 20_not_pivot
# 21_not_pivot
# 22_not_pivot
# 23_not_pivot
# 24_not_pivot
# 25_not_pivot
# 26_not_pivot
# 27_not_pivot
# 28_not_pivot
# 29_not_pivot
# 30_not_pivot
# 31_not_pivot
# 32_not_pivot
# 33_not_pivot
# 34_not_pivot
# 35_not_pivot
# 36_not_pivot
# 37_not_pivot
# 38_not_pivot
# 39_not_pivot
# 40_not_pivot
# 41_not_pivot
# 42_not_pivot
# 43_not_pivot
# 44_not_pivot
# 45_not_pivot
# 46_not_pivot
# 47_not_pivot
# 48_not_pivot
# 49_not_pivot
# 50_not_pivot
# 51_not_pivot
# 52_not_pivot
# 53_not_pivot
# 54_not_pivot
# 55_not_pivot
# 56_not_pivot
# 57_not_pivot
# 58_not_pivot
# 59_not_pivot
# 60_not_pivot
# 61_not_pivot
# 62_not_pivot
# 63_not_pivot
# 64_not_pivot
# 65_not_pivot
# 66_not_pivot
# 67_not_pivot
# 68_not_pivot
# 69_not_pivot
# 70_not_pivot
# 71_not_pivot
# 72_not_pivot
# 73_not_pivot
# 74_not_pivot
# 75_not_pivot
# 76_not_pivot
# 77_not_pivot
# 78_not_pivot
# 79_not_pivot
# 80_not_pivot
# 81_not_pivot
# 82_not_pivot
# 83_not_pivot
# 84_not_pivot
# 85_not_pivot
# 86_not_pivot
# 87_not_pivot
# 88_not_pivot
# 89_not_pivot
# 90_not_pivot
# 91_not_pivot
# 92_not_pivot
# 93_not_pivot
# 94_not_pivot
# 95_not_pivot
# 96_not_pivot
# 97_not_pivot
# 98_not_pivot
# 99_not_pivot
# 100_not_pivot
# 101_not_pivot
# 102_not_pivot
# 103_not_pivot
# 104_not_pivot
# 105_not_pivot
# 106_not_pivot
# 107_not_pivot
# 108_not_pivot
# 109_not_pivot
# 110_not_pivot
# 111_not_pivot
# 112_not_pivot
# 113_not_pivot
# 114_not_pivot
# 115_not_pivot
# 116_not_pivot
# 117_not_pivot
# 118_not_pivot
# 119_not_pivot
# 120_not_pivot
# 121_not_pivot
# 122_not_pivot
# 123_not_pivot
# 124_not_pivot
# 125_not_pivot
# 126_not_pivot
# 127_not_pivot
# 128_not_pivot
# 129_not_pivot
# 130_not_pivot
# 131_not_pivot
# 132_not_pivot
# 133_not_pivot
# 134_not_pivot
# 135_not_pivot
# 136_not_pivot
# 137_not_pivot
# 138_not_pivot
# 139_not_pivot
# 140_not_pivot
# 141_not_pivot
# 142_not_pivot
# 143_not_pivot
# 144_not_pivot
# 145_not_pivot
# 146_not_pivot
# 147_not_pivot
# 148_not_pivot
# 149_not_pivot
# 150_not_pivot
# 151_not_pivot
# 152_not_pivot
# 153_not_pivot
# 154_not_pivot
# 155_not_pivot
# 156_not_pivot
# 157_not_pivot
# 158_not_pivot
# 159_not_pivot
# 160_not_pivot
# 161_not_pivot
# 162_not_pivot
# 163_not_pivot
# 164_not_pivot
# 165_not_pivot
# 166_not_pivot
# 167_not_pivot
# 168_not_pivot
# 169_not_pivot
# 170_not_pivot
# 171_not_pivot
# 172_not_pivot
# 173_not_pivot
# 174_not_pivot
# 175_not_pivot
# 176_not_pivot
# 177_not_pivot
# 178_not_pivot
# 179_not_pivot
# 180_not_pivot
# 181_not_pivot
# 182_not_pivot
# 183_not_pivot
# 184_not_pivot
# 185_not_pivot
# 186_not_pivot
# 187_not_pivot
# 188_not_pivot
# 189_not_pivot
# 190_not_pivot
# 191_not_pivot
# 192_not_pivot
# 193_not_pivot
# 194_not_pivot
# 195_not_pivot
# 196_not_pivot
# 197_not_pivot
# 198_not_pivot
# 199_not_pivot
# 200_not_pivot
# 201_not_pivot
# 202_not_pivot
# 203_not_pivot
# 204_not_pivot
# 205_not_pivot
# 206_not_pivot
# 207_not_pivot
# 208_not_pivot
# 209_not_pivot
# 210_not_pivot
# 211_not_pivot
# 212_not_pivot
# 213_not_pivot
# 214_not_pivot
# 215_not_pivot
# 216_not_pivot
# 217_not_pivot
# 218_not_pivot
# 219_not_pivot
# 220_not_pivot
# 221_not_pivot
# 222_not_pivot
# 223_not_pivot
# 224_not_pivot
# 225_not_pivot
# 226_not_pivot
# 227_not_pivot
# 228_not_pivot
# 229_not_pivot
# 230_not_pivot
# 231_not_pivot
# 232_not_pivot
# 233_not_pivot
# 234_not_pivot
# 235_not_pivot
# 236_not_pivot
# 237_not_pivot
# 238_not_pivot
# 239_not_pivot
# 240_not_pivot
# 241_not_pivot
# 242_not_pivot
# 243_not_pivot
# 244_not_pivot
# 245_not_pivot
# 246_not_pivot
# 247_not_pivot
# 248_not_pivot
# 249_not_pivot
# 250_not_pivot
# 251_not_pivot
# 252_not_pivot
# 253_not_pivot
# 254_not_pivot
# 255_not_pivot
# 256_not_pivot
# 257_not_pivot
# 258_not_pivot
# 259_not_pivot
# 260_not_pivot
# 261_not_pivot
# 262_not_pivot
# 263_not_pivot
# 264_not_pivot
# 265_not_pivot
# 266_not_pivot
# 267_not_pivot
# 268_not_pivot
# 269_not_pivot
# 270_not_pivot
# 271_not_pivot
# 272_not_pivot
# 273_not_pivot
# 274_not_pivot
# 275_not_pivot
# 276_not_pivot
# 277_not_pivot
# 278_not_pivot
# 279_not_pivot
# 280_not_pivot
# 281_not_pivot
# 282_not_pivot
# 283_not_pivot
# 284_not_pivot
# 285_not_pivot
# 286_not_pivot
# 287_not_pivot
# 288_not_pivot
# 289_not_pivot
# 290_not_pivot
# 291_not_pivot
# 292_not_pivot
# 293_not_pivot
# 294_not_pivot
# 295_not_pivot
# 296_not_pivot
# 297_not_pivot
# 298_not_pivot
# 299_not_pivot
# 300_not_pivot
# 301_not_pivot
# 302_not_pivot
# 303_not_pivot
# 304_not_pivot
# 305_not_pivot
# 306_not_pivot
# 307_not_pivot
# 308_not_pivot
# 309_not_pivot
# 310_not_pivot
# 311_not_pivot
# 312_not_pivot
# 313_not_pivot
# 314_not_pivot
# 315_not_pivot
# 316_not_pivot
# 317_not_pivot
# 318_not_pivot
# 319_not_pivot
# 320_not_pivot
# 321_not_pivot
# 322_not_pivot
# 323_not_pivot
# 324_not_pivot
# 325_not_pivot
# 326_not_pivot
# 327_not_pivot
# 328_not_pivot
# 329_not_pivot
# 330_not_pivot
# 331_not_pivot
# 332_not_pivot
# 333_not_pivot
# 334_not_pivot
# 335_not_pivot
# 336_not_pivot
# 337_not_pivot
# 338_not_pivot
# 339_not_pivot
# 340_not_pivot
# 341_not_pivot
# 342_not_pivot
# 343_not_pivot
# 344_not_pivot
# 345_not_pivot
# 346_not_pivot
# 347_not_pivot
# 348_not_pivot
# 349_not_pivot
# 350_not_pivot
# 351_not_pivot
# 352_not_pivot
# 353_not_pivot
# 354_not_pivot
# 355_not_pivot
# 356_not_pivot
# 357_not_pivot
# 358_not_pivot
# 359_not_pivot
# 360_not_pivot
# 361_not_pivot
# 362_not_pivot
# 363_not_pivot
# 364_not_pivot
# 365_not_pivot
# 366_not_pivot
# 367_not_pivot
# 368_not_pivot
# 369_not_pivot
# 370_not_pivot
# 371_not_pivot
# 372_not_pivot
# 373_not_pivot
# 374_not_pivot
# 375_not_pivot
# 376_not_pivot
# 377_not_pivot
# 378_not_pivot
# 379_not_pivot
# 380_not_pivot
# 381_not_pivot
# 382_not_pivot
# 383_not_pivot
# 384_not_pivot
# 385_not_pivot
# 386_not_pivot
# 387_not_pivot
# 388_not_pivot
# 389_not_pivot
# 390_not_pivot
# 391_not_pivot
# 392_not_pivot
# 393_not_pivot
# 394_not_pivot
# 395_not_pivot
# 396_not_pivot
# 397_not_pivot
# 398_not_pivot
# 399_not_pivot
# 400_not_pivot
# 401_not_pivot
# 402_not_pivot
# 403_not_pivot
# 404_not_pivot
# 405_not_pivot
# 406_not_pivot
# 407_not_pivot
# 408_not_pivot
# 409_not_pivot
# 410_not_pivot
# 411_not_pivot
# 412_not_pivot
# 413_not_pivot
# 414_not_pivot
# 415_not_pivot
# 416_not_pivot
# 417_not_pivot
# 418_not_pivot
# 419_not_pivot
# 420_not_pivot
# 421_not_pivot
# 422_not_pivot
# 423_not_pivot
# 424_not_pivot
# 425_not_pivot
# 426_not_pivot
# 427_not_pivot
# 428_not_pivot
# 429_not_pivot
# 430_not_pivot
# 431_not_pivot
# 432_not_pivot
# 433_not_pivot
# 434_not_pivot
# 435_not_pivot
# 436_not_pivot
# 437_not_pivot
# 438_not_pivot
# 439_not_pivot
# 440_not_pivot
# 441_not_pivot
# 442_not_pivot
# 443_not_pivot
# 444_not_pivot
# 445_not_pivot
# 446_not_pivot
# 447_not_pivot
# 448_not_pivot
# 449_not_pivot
# 450_not_pivot
# 451_not_pivot
# 452_not_pivot
# 453_not_pivot
# 454_not_pivot
# 455_not_pivot
# 456_not_pivot
# 457_not_pivot
# 458_not_pivot
# 459_not_pivot
# 460_not_pivot
# 461_not_pivot
# 462_not_pivot
# 463_not_pivot
# 464_not_pivot
# 465_not_pivot
# 466_not_pivot
# 467_not_pivot
# 468_not_pivot
# 469_not_pivot
# 470_not_pivot
# 471_not_pivot
# 472_not_pivot
# 473_not_pivot
# 474_not_pivot
# 475_not_pivot
# 476_not_pivot
# 477_not_pivot
# 478_not_pivot
# 479_not_pivot
# 480_not_pivot
# 481_not_pivot
# 482_not_pivot
# 483_not_pivot
# 484_not_pivot
# 485_not_pivot
# 486_not_pivot
# 487_not_pivot
# 488_not_pivot
# 489_not_pivot
# 490_not_pivot
# 491_not_pivot
# 492_not_pivot
# 493_not_pivot
# 494_not_pivot
# 495_not_pivot
# 496_not_pivot
# 497_not_pivot
# 498_not_pivot
# 499_not_pivot
# 500_not_pivot
# 501_not_pivot
# 502_not_pivot
# 503_not_pivot
# 504_not_pivot
# 505_not_pivot
# 506_not_pivot
# 507_not_pivot
# 508_not_pivot
# 509_not_pivot
# 510_not_pivot
# 511_not_pivot
# 512_not_pivot
# 513_not_pivot
# 514_not_pivot
# 515_not_pivot
# 516_not_pivot
# 517_not_pivot
# 518_not_pivot
# 519_not_pivot
# 520_not_pivot
# 521_not_pivot
# 522_not_pivot
# 523_not_pivot
# 524_not_pivot
# 525_not_pivot
# 526_not_pivot
# 527_not_pivot
# 528_not_pivot
# 529_not_pivot
# 530_not_pivot
# 531_not_pivot
# 532_not_pivot
# 533_not_pivot
# 534_not_pivot
# 535_not_pivot
# 536_not_pivot
# 537_not_pivot
# 538_not_pivot
# 539_not_pivot
# 540_not_pivot
# 541_not_pivot
# 542_not_pivot
# 543_not_pivot
# 544_not_pivot
# 545_not_pivot
# 546_not_pivot
# 547_not_pivot
# 548_not_pivot
# 549_not_pivot
# 550_not_pivot
# 551_not_pivot
# 552_not_pivot
# 553_not_pivot
# 554_not_pivot
# 555_not_pivot
# 556_not_pivot
# 557_not_pivot
# 558_not_pivot
# 559_not_pivot
# 560_not_pivot
# 561_not_pivot
# 562_not_pivot
# 563_not_pivot
# 564_not_pivot
# 565_not_pivot
# 566_not_pivot
# 567_not_pivot
# 568_not_pivot
# 569_not_pivot
# 570_not_pivot
# 571_not_pivot
# 572_not_pivot
# 573_not_pivot
# 574_not_pivot
# 575_not_pivot
# 576_not_pivot
# 577_not_pivot
# 578_not_pivot
# 579_not_pivot
# 580_not_pivot
# 581_not_pivot
# 582_not_pivot
# 583_not_pivot
# 584_not_pivot
# 585_not_pivot
# 586_not_pivot
# 587_not_pivot
# 588_not_pivot
# 589_not_pivot
# 590_not_pivot
# 591_not_pivot
# 592_not_pivot
# 593_not_pivot
# 594_not_pivot
# 595_not_pivot
# 596_not_pivot
# 597_not_pivot
# 598_not_pivot
# 599_not_pivot
# 600_not_pivot
# 601_not_pivot
# 602_not_pivot
# 603_not_pivot
# 604_not_pivot
# 605_not_pivot
# 606_not_pivot
# 607_not_pivot
# 608_not_pivot
# 609_not_pivot
# 610_not_pivot
# 611_not_pivot
# 612_not_pivot
# 613_not_pivot
# 614_not_pivot
# 615_not_pivot
# 616_not_pivot
# 617_not_pivot
# 618_not_pivot
# 619_not_pivot
# 620_not_pivot
# 621_not_pivot
# 622_not_pivot
# 623_not_pivot
# 624_not_pivot
# 625_not_pivot
# 626_not_pivot
# 627_not_pivot
# 628_not_pivot
# 629_not_pivot
# 630_not_pivot
# 631_not_pivot
# 632_not_pivot
# 633_not_pivot
# 634_not_pivot
# 635_not_pivot
# 636_not_pivot
# 637_not_pivot
# 638_not_pivot
# 639_not_pivot
# 640_not_pivot
# 641_not_pivot
# 642_not_pivot
# 643_not_pivot
# 644_not_pivot
# 645_not_pivot
# 646_not_pivot
# 647_not_pivot
# 648_not_pivot
# 649_not_pivot
# 650_not_pivot
# 651_not_pivot
# 652_not_pivot
# 653_not_pivot
# 654_not_pivot
# 655_not_pivot
# 656_not_pivot
# 657_not_pivot
# 658_not_pivot
# 659_not_pivot
# 660_not_pivot
# 661_not_pivot
# 662_not_pivot
# 663_not_pivot
# 664_not_pivot
# 665_not_pivot
# 666_not_pivot
# 667_not_pivot
# 668_not_pivot
# 669_not_pivot
# 670_not_pivot
# 671_not_pivot
# 672_not_pivot
# 673_not_pivot
# 674_not_pivot
# 675_not_pivot
# 676_not_pivot
# 677_not_pivot
# 678_not_pivot
# 679_not_pivot
# 680_not_pivot
# 681_not_pivot
# 682_not_pivot
# 683_not_pivot
# 684_not_pivot
# 685_not_pivot
# 686_not_pivot
# 687_not_pivot
# 688_not_pivot
# 689_not_pivot
# 690_not_pivot
# 691_not_pivot
# 692_not_pivot
# 693_not_pivot
# 694_not_pivot
# 695_not_pivot
# 696_not_pivot
# 697_not_pivot
# 698_not_pivot
# 699_not_pivot

# %%
X = np.array(X)
Y = np.array(Y)

# %%
print(X.shape)
print(Y.shape)
# Out:
# (2506, 256, 256, 3)
# (2506,)

# %% [markdown]
# Plotamos um exemplo:

# %%
i=2400
plt.figure(figsize=[6,6])
plt.title(class_list[Y[i]])
plt.imshow(X[i,:,:,:])
plt.axis('off')
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %% [markdown]
# Vamos dividir os dados em treinamento e teste:

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=10)

# %% [markdown]
# ### AlexNet

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# AlexNet é o nome de uma rede neural convolucional que teve um grande impacto no campo do aprendizado de máquina, especificamente na aplicação de aprendizado profundo à visão de máquina. Ele ganhou a famosa competição ImageNet LSVRC-2012 de 2012 por uma grande margem (15,3% VS 26,2% (segundo lugar) taxas de erro). A rede tinha uma arquitetura muito semelhante à LeNet de Yann LeCun et al, mas era mais profunda, com mais filtros por camada e com camadas convolucionais empilhadas. Consistia em 11 × 11, 5 × 5, 3 × 3, convolutions, max pooling, dropout, data augmentation, ReLU activations, SGD with momentum. Ele anexou ativações ReLU após cada camada convolucional e totalmente conectada. AlexNet foi treinado por 6 dias simultaneamente em duas GPUs Nvidia Geforce GTX 580, razão pela qual sua rede é dividida em dois pipelines.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A arquitetura representada na figura acima, o AlexNet contém oito camadas com pesos; os cinco primeiros são convolucionais e os três restantes são totalmente conectados. A saída da última camada totalmente conectada é alimentada para um softmax de 1000 vias que produz uma distribuição sobre os 1000 rótulos de classe. A rede maximiza o objetivo da regressão logística multinomial, que é equivalente a maximizar a média entre os casos de treinamento da probabilidade logarítmica do rótulo correto sob a distribuição de previsão. Os kernels da segunda, quarta e quinta camadas convolucionais são conectados apenas aos mapas de kernel na camada anterior que residem na mesma GPU. Os kernels da terceira camada convolucional são conectados a todos os mapas de kernel na segunda camada. Os neurônios nas camadas totalmente conectadas são conectados a todos os neurônios na camada anterior.
# Resumindo, o AlexNet contém 5 camadas convolucionais e 3 camadas totalmente conectadas. Relu é aplicado após uma camada muito convolucional e totalmente conectada. O abandono é aplicado antes do primeiro e do segundo ano totalmente conectado. A rede tem 62,3 milhões de parâmetros e precisa de 1,1 bilhão de unidades de computação em uma passagem direta. Também podemos ver as camadas de convolução, que representam 6% de todos os parâmetros, consomem 95% da computação.

# %% [markdown]
# Vamos agora aplicar a AlexNet ao nosso dataset:

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization, Dropout, Activation, ZeroPadding2D
from keras.regularizers import l2
from tensorflow.keras.optimizers.legacy import Adam

# %%
def alexnet_model(img_shape=(224, 224, 3),l2_reg=0.,weights=None):

	# Initialize model
	alexnet = Sequential()

	# Layer 1
	alexnet.add(Conv2D(96, (11, 11), input_shape=img_shape,padding='same', kernel_regularizer=l2(l2_reg)))
	alexnet.add(BatchNormalization())
	alexnet.add(Activation('relu'))
	alexnet.add(MaxPooling2D(pool_size=(2, 2)))

	# Layer 2
	alexnet.add(Conv2D(256, (5, 5), padding='same'))
	alexnet.add(BatchNormalization())
	alexnet.add(Activation('relu'))
	alexnet.add(MaxPooling2D(pool_size=(2, 2)))

	# Layer 3
	alexnet.add(ZeroPadding2D((1, 1)))
	alexnet.add(Conv2D(512, (3, 3), padding='same'))
	alexnet.add(BatchNormalization())
	alexnet.add(Activation('relu'))
	alexnet.add(MaxPooling2D(pool_size=(2, 2)))

	# Layer 4
	alexnet.add(ZeroPadding2D((1, 1)))
	alexnet.add(Conv2D(1024, (3, 3), padding='same'))
	alexnet.add(BatchNormalization())
	alexnet.add(Activation('relu'))

	# Layer 5
	alexnet.add(ZeroPadding2D((1, 1)))
	alexnet.add(Conv2D(1024, (3, 3), padding='same'))
	alexnet.add(BatchNormalization())
	alexnet.add(Activation('relu'))
	alexnet.add(MaxPooling2D(pool_size=(2, 2)))

	# Layer 6
	alexnet.add(Flatten())
	alexnet.add(Dense(3072))
	alexnet.add(BatchNormalization())
	alexnet.add(Activation('relu'))
	alexnet.add(Dropout(0.5))

	# Layer 7
	alexnet.add(Dense(4096))
	alexnet.add(BatchNormalization())
	alexnet.add(Activation('relu'))
	alexnet.add(Dropout(0.5))

	# Layer 8
	alexnet.add(Dense(1))
	alexnet.add(BatchNormalization())
	alexnet.add(Activation('sigmoid'))

	if weights is not None:
		alexnet.load_weights(weights)

	return alexnet

# %%
input_shape = x_train.shape[1:]

# %%
model = alexnet_model(img_shape=input_shape)
model.compile(loss='binary_crossentropy', optimizer=Adam(lr=0.00001, decay=1e-6), metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 96)      34944
#
#  batch_normalization (BatchN  (None, 256, 256, 96)     384
#  ormalization)
#
#  activation (Activation)     (None, 256, 256, 96)      0
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 96)     0
#  )
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
#  conv2d_1 (Conv2D)           (None, 128, 128, 256)     614656
#
#  batch_normalization_1 (Batc  (None, 128, 128, 256)    1024
#  hNormalization)
#
#  activation_1 (Activation)   (None, 128, 128, 256)     0
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 256)      0
#  2D)
#
#  zero_padding2d (ZeroPadding  (None, 66, 66, 256)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 66, 66, 512)       1180160
#
#  batch_normalization_2 (Batc  (None, 66, 66, 512)      2048
#  hNormalization)
#
#  activation_2 (Activation)   (None, 66, 66, 512)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 33, 33, 512)      0
#  2D)
#
#  zero_padding2d_1 (ZeroPaddi  (None, 35, 35, 512)      0
#  ng2D)
#
#  conv2d_3 (Conv2D)           (None, 35, 35, 1024)      4719616
#
#  batch_normalization_3 (Batc  (None, 35, 35, 1024)     4096
#  hNormalization)
#
#  activation_3 (Activation)   (None, 35, 35, 1024)      0
#
#  zero_padding2d_2 (ZeroPaddi  (None, 37, 37, 1024)     0
#  ng2D)
#
#  conv2d_4 (Conv2D)           (None, 37, 37, 1024)      9438208
#
#  batch_normalization_4 (Batc  (None, 37, 37, 1024)     4096
#  hNormalization)
#
#  activation_4 (Activation)   (None, 37, 37, 1024)      0
#
#  max_pooling2d_3 (MaxPooling  (None, 18, 18, 1024)     0
#  2D)
#
#  flatten (Flatten)           (None, 331776)            0
#
#  dense (Dense)               (None, 3072)              1019218944
#
#  batch_normalization_5 (Batc  (None, 3072)             12288
#  hNormalization)
#
#  activation_5 (Activation)   (None, 3072)              0
#
#  dropout (Dropout)           (None, 3072)              0
#
#  dense_1 (Dense)             (None, 4096)              12587008
#
#  batch_normalization_6 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  activation_6 (Activation)   (None, 4096)              0
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 1)                 4097
#
#  batch_normalization_7 (Batc  (None, 1)                4
#  hNormalization)
#
#  activation_7 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 1,047,837,957
# Trainable params: 1,047,817,795
# Non-trainable params: 20,162
# _________________________________________________________________

# %%
history = model.fit(x = x_train, y= y_train, batch_size=8, epochs=50, verbose=1, shuffle=True, validation_split= 0.2)
# Out:
# Epoch 1/50
# 176/176 [==============================] - 34s 106ms/step - loss: 0.5696 - accuracy: 0.7256 - val_loss: 0.9199 - val_accuracy: 0.2906
# Epoch 2/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.4743 - accuracy: 0.8346 - val_loss: 0.5215 - val_accuracy: 0.7578
# Epoch 3/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.4506 - accuracy: 0.8710 - val_loss: 0.4596 - val_accuracy: 0.8718
# Epoch 4/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.4446 - accuracy: 0.8895 - val_loss: 0.3986 - val_accuracy: 0.9259
# Epoch 5/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.4305 - accuracy: 0.9095 - val_loss: 0.5158 - val_accuracy: 0.7949
# Epoch 6/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.4274 - accuracy: 0.9216 - val_loss: 0.3813 - val_accuracy: 0.9259
# Epoch 7/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.4082 - accuracy: 0.9465 - val_loss: 0.3867 - val_accuracy: 0.9288
# Epoch 8/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.4093 - accuracy: 0.9530 - val_loss: 0.4496 - val_accuracy: 0.8889
# Epoch 9/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.4085 - accuracy: 0.9451 - val_loss: 0.4524 - val_accuracy: 0.8832
# Epoch 10/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.4061 - accuracy: 0.9494 - val_loss: 0.4505 - val_accuracy: 0.8974
# Epoch 11/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.4100 - accuracy: 0.9501 - val_loss: 0.4824 - val_accuracy: 0.8689
# Epoch 12/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.4076 - accuracy: 0.9551 - val_loss: 0.3847 - val_accuracy: 0.9288
# Epoch 13/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.4060 - accuracy: 0.9508 - val_loss: 0.4256 - val_accuracy: 0.9316
# Epoch 14/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.4175 - accuracy: 0.9487 - val_loss: 0.4499 - val_accuracy: 0.9060
# Epoch 15/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.4132 - accuracy: 0.9437 - val_loss: 0.5493 - val_accuracy: 0.7607
# Epoch 16/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.4049 - accuracy: 0.9544 - val_loss: 0.4110 - val_accuracy: 0.9345
# Epoch 17/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.4022 - accuracy: 0.9572 - val_loss: 0.4879 - val_accuracy: 0.8632
# Epoch 18/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.3962 - accuracy: 0.9644 - val_loss: 0.4216 - val_accuracy: 0.9316
# Epoch 19/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.3982 - accuracy: 0.9558 - val_loss: 0.4109 - val_accuracy: 0.9288
# Epoch 20/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.4062 - accuracy: 0.9508 - val_loss: 0.4284 - val_accuracy: 0.9430
# Epoch 21/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.4119 - accuracy: 0.9558 - val_loss: 0.4007 - val_accuracy: 0.9259
# Epoch 22/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.4010 - accuracy: 0.9594 - val_loss: 0.3996 - val_accuracy: 0.9288
# Epoch 23/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.4016 - accuracy: 0.9629 - val_loss: 0.4561 - val_accuracy: 0.8974
# Epoch 24/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.4022 - accuracy: 0.9530 - val_loss: 0.3962 - val_accuracy: 0.9288
# Epoch 25/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.3911 - accuracy: 0.9708 - val_loss: 0.4219 - val_accuracy: 0.9288
# Epoch 26/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.4022 - accuracy: 0.9572 - val_loss: 0.4451 - val_accuracy: 0.9231
# Epoch 27/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.4038 - accuracy: 0.9544 - val_loss: 0.4508 - val_accuracy: 0.9031
# Epoch 28/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.3934 - accuracy: 0.9694 - val_loss: 0.4056 - val_accuracy: 0.9288
# Epoch 29/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.3930 - accuracy: 0.9665 - val_loss: 0.4060 - val_accuracy: 0.9231
# Epoch 30/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.3912 - accuracy: 0.9672 - val_loss: 0.4472 - val_accuracy: 0.9316
# Epoch 31/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.3965 - accuracy: 0.9601 - val_loss: 0.4884 - val_accuracy: 0.8547
# Epoch 32/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.3927 - accuracy: 0.9615 - val_loss: 0.4461 - val_accuracy: 0.9145
# Epoch 33/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.3845 - accuracy: 0.9751 - val_loss: 0.4038 - val_accuracy: 0.9373
# Epoch 34/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.3910 - accuracy: 0.9636 - val_loss: 0.4685 - val_accuracy: 0.8860
# Epoch 35/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.3867 - accuracy: 0.9729 - val_loss: 0.4372 - val_accuracy: 0.9345
# Epoch 36/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.4004 - accuracy: 0.9594 - val_loss: 0.4407 - val_accuracy: 0.9202
# Epoch 37/50
# 176/176 [==============================] - 13s 73ms/step - loss: 0.3804 - accuracy: 0.9722 - val_loss: 0.4482 - val_accuracy: 0.9231
# Epoch 38/50
# 176/176 [==============================] - 13s 73ms/step - loss: 0.3807 - accuracy: 0.9758 - val_loss: 0.4242 - val_accuracy: 0.9288
# Epoch 39/50
# 176/176 [==============================] - 13s 73ms/step - loss: 0.3983 - accuracy: 0.9501 - val_loss: 0.4211 - val_accuracy: 0.9259
# Epoch 40/50
# 176/176 [==============================] - 13s 73ms/step - loss: 0.4073 - accuracy: 0.9444 - val_loss: 0.4362 - val_accuracy: 0.9174
# Epoch 41/50
# 176/176 [==============================] - 13s 73ms/step - loss: 0.3962 - accuracy: 0.9501 - val_loss: 0.4000 - val_accuracy: 0.9316
# Epoch 42/50
# 176/176 [==============================] - 13s 73ms/step - loss: 0.3810 - accuracy: 0.9686 - val_loss: 0.4248 - val_accuracy: 0.9231
# Epoch 43/50
# 176/176 [==============================] - 13s 73ms/step - loss: 0.3965 - accuracy: 0.9494 - val_loss: 0.4197 - val_accuracy: 0.9288
# Epoch 44/50
# 176/176 [==============================] - 13s 73ms/step - loss: 0.3902 - accuracy: 0.9679 - val_loss: 0.4660 - val_accuracy: 0.8917
# Epoch 45/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.3873 - accuracy: 0.9651 - val_loss: 0.4075 - val_accuracy: 0.9231
# Epoch 46/50
# 176/176 [==============================] - 13s 73ms/step - loss: 0.3848 - accuracy: 0.9651 - val_loss: 0.4238 - val_accuracy: 0.9345
# Epoch 47/50
# 176/176 [==============================] - 13s 73ms/step - loss: 0.3852 - accuracy: 0.9665 - val_loss: 0.4171 - val_accuracy: 0.9316
# Epoch 48/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.3823 - accuracy: 0.9658 - val_loss: 0.4290 - val_accuracy: 0.9231
# Epoch 49/50
# 176/176 [==============================] - 13s 73ms/step - loss: 0.3872 - accuracy: 0.9644 - val_loss: 0.4627 - val_accuracy: 0.8718
# Epoch 50/50
# 176/176 [==============================] - 13s 73ms/step - loss: 0.3841 - accuracy: 0.9679 - val_loss: 0.3934 - val_accuracy: 0.9316

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='lower right')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()
